# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/r-xue/casa_proc/blob/master/demo/test_casaproc.ipynb)

# %%
import sys
import glob
import os
import io
import logging
from pprint import pprint

print(sys.version)

import socket 
if  'hypersion' or 'mini' in socket.gethostname() :
    os.chdir('/Users/Rui/Dropbox/Worklib/projects/GMaKE/examples/output/')
print(socket.gethostname())
print(os.getcwd())

import gmake
print(gmake.__version__)
print(gmake.__email__)
print(gmake.__demo__)

inpfile=gmake.__demo__+'/../examples/inpfile/bx610_band6_uv_ab.inp'
logfile=''

print('>'*40)
#gmake.logger_config()
#gmake.logger_status()
#import pprint
#pprint.pprint(logging.Logger.manager.loggerDict) 
gmake.logger_config()
inp_dct=gmake.read_inp(inpfile)
outdir=inp_dct['optimize']['outdir']
gmake.logger_config(logfile=outdir+'/gmake.log',loglevel='DEBUG',logfilelevel='DEBUG')
gmake.logger_status()
# Out:
# 3.7.4 (default, Sep  7 2019, 19:52:29)
# [Clang 10.0.1 (clang-1001.0.46.4)]
# hyperion
# /Users/Rui/Dropbox/Worklib/projects/GMaKE/examples/output
# 0.1.dev3
# rx.astro@gmail.com
# /Users/Rui/Dropbox/Worklib/projects/GMaKE/gmake
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# <Logger gmake (DEBUG)>
# [<FileHandler /Users/Rui/Dropbox/Worklib/projects/GMaKE/examples/output/bx610_band6_uv_ab/gmake.log (DEBUG)>, <StreamHandler stderr (DEBUG)>]

# %%
dat_dct=gmake.read_data(inp_dct,fill_mask=True,fill_error=True)
# Out:
# loading: ../data/bx610/alma/band6/bx610_band6.bb2.cube3.ms
#
# data@../data/bx610/alma/band6/bx610_band6.bb2.cube3.ms>>(515942, 79)310.97 MB
# uvw@../data/bx610/alma/band6/bx610_band6.bb2.cube3.ms>>(515942, 3)5.9 MB
# weight@../data/bx610/alma/band6/bx610_band6.bb2.cube3.ms>>(515942,)1.97 MB156.00705
# chanfreq@../data/bx610/alma/band6/bx610_band6.bb2.cube3.ms>> [GHz]250.77629494180084252.6042642340366379
# chanwidth@../data/bx610/alma/band6/bx610_band6.bb2.cube3.ms>> [GHz]0.023435503746612550.023435503746612550.02343550374661255
# phasecenter@../data/bx610/alma/band6/bx610_band6.bb2.cube3.ms>>[356.53933333  12.82202778]
#
# loading: ../data/bx610/alma/band6/bx610_band6.bb3.cube3.ms
#
# data@../data/bx610/alma/band6/bx610_band6.bb3.cube3.ms>>(489423, 79)294.99 MB
# uvw@../data/bx610/alma/band6/bx610_band6.bb3.cube3.ms>>(489423, 3)5.6 MB
# weight@../data/bx610/alma/band6/bx610_band6.bb3.cube3.ms>>(489423,)1.87 MB179.50488
# chanfreq@../data/bx610/alma/band6/bx610_band6.bb3.cube3.ms>> [GHz]233.2777854774409235.1057547696790479
# chanwidth@../data/bx610/alma/band6/bx610_band6.bb3.cube3.ms>> [GHz]-0.023435503746643067-0.023435503746643067-0.023435503746643067
# phasecenter@../data/bx610/alma/band6/bx610_band6.bb3.cube3.ms>>[356.53933333  12.82202778]
#
# loading: ../data/bx610/alma/band6/bx610_band6.bb1.mfs.ms
#
# data@../data/bx610/alma/band6/bx610_band6.bb1.mfs.ms>>(515942, 1)3.94 MB
# uvw@../data/bx610/alma/band6/bx610_band6.bb1.mfs.ms>>(515942, 3)5.9 MB
# weight@../data/bx610/alma/band6/bx610_band6.bb1.mfs.ms>>(515942,)1.97 MB3660.7656
# chanfreq@../data/bx610/alma/band6/bx610_band6.bb1.mfs.ms>> [GHz]250.0968783125849250.09687831258491
# chanwidth@../data/bx610/alma/band6/bx610_band6.bb1.mfs.ms>> [GHz]1.81241907798936451.81241907798936451.8124190779893645
# phasecenter@../data/bx610/alma/band6/bx610_band6.bb1.mfs.ms>>[356.53933333  12.82202778]
#
# loading: ../data/bx610/alma/band6/bx610_band6.bb4.mfs.ms
#
# data@../data/bx610/alma/band6/bx610_band6.bb4.mfs.ms>>(515942, 1)3.94 MB
# uvw@../data/bx610/alma/band6/bx610_band6.bb4.mfs.ms>>(515942, 3)5.9 MB
# weight@../data/bx610/alma/band6/bx610_band6.bb4.mfs.ms>>(515942,)1.97 MB5153.2075
# chanfreq@../data/bx610/alma/band6/bx610_band6.bb4.mfs.ms>> [GHz]235.8799719934693235.87997199346931
# chanwidth@../data/bx610/alma/band6/bx610_band6.bb4.mfs.ms>> [GHz]-1.859287724233795-1.859287724233795-1.859287724233795
# phasecenter@../data/bx610/alma/band6/bx610_band6.bb4.mfs.ms>>[356.53933333  12.82202778]

# %%
fit_dct,sampler=gmake.fit_setup(inp_dct,dat_dct)
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# optimizing parameters: index / name / start / lo_limit / up_limit
# ++++++++++++++++++++++++++++++++++++++++
# @ object
# ----------------------------------------
# name                 : ''          ''      str
# note                 : ''          ''      str
# image                : ''          ''      str
# error                : ''          ''      str
# mask                 : ''          ''      str
# psf                  : ''          ''      str
# bmaj                 : None        ''      float
# bmin                 : None        ''      float
# bpa                  : None        ''      float
# samp                 : ''          ''      str
# vis                  : ''          ''      str
# pmodel               : ''          ''      str
# type                 : ''          ''      str
# xypos                : [0.0,0.0]   '.7f'   list
# xypos_kin            : [0.0,0.0]   '.7f'   list
# z                    : 0.0         '.3f'   float
# vsys                 : 0.0         '.2f'   float
# sbrp                 : [1.0,1.0]   '.2f'   list
# ge_pa                : 90.0        '.2f'   float
# ge_q                 : 2.0         '.2f'   float
# pa                   : 0.0         '.2f'   float
# inc                  : 0.0         '.2f'   float
# sbser                : [1.0,1.0]   '.2f'   list
# intflux              : 1.0         '.2f'   float
# restwave             : 1000.0      ''      float
# restfreq             : 100.0       ''      float
# method               : 'kinmspy'   ''      str
# sbvp                 : 0.0         '.2f'   float
# vrad                 : [0.0,0.1]   '.2f'   list
# vrot                 : [100,100]   '.2f'   list
# vdis                 : [10.0,10.0] '.2f'   list
# alpha                : 0.0         '.2f'   float
# ++++++++++++++++++++++++++++++++++++++++
# @ potential
# ----------------------------------------
# disk_sd              : 0.0                 float
# disk_rs              : 1.0                 float
# disk_sb2sd           : ('object',1)        tuple
# halo_ms              : 5e10                float
# halo_a               : 100.0               float
# halo_conv            : 4.0                 float
# halo_mvir            : 0.5                 float
# ++++++++++++++++++++++++++++++++++++++++
# @ optimize
# ----------------------------------------
# method               : 'amoeba'            str
# niter                : 100                 int
# outname_replace      : []                  list
# outname_exclude      : []                  list
# outdir               : 'testdir'           str
# parname@objectname   : ('o',-1,1,0.0)      tuple
# parname[a:b]@obectname : ('o',-1,1,0.0)      tuple
# ++++++++++++++++++++++++++++++++++++++++
# @ comments
# ----------------------------------------
#  0   vsys@co76          115.00      (    -120.00   ,     280.00     )
#  1   vrot[1:5]@co76     220.00      (     0.00     ,     800.00     )
#  2   vdis[0:5]@co76      20.00      (     0.00     ,     800.00     )
#  3   pa@co76            -62.00      (    -142.00   ,      18.00     )
#  4   inc@co76            40.00      (     5.00     ,      85.00     )
#  5   xypos[0]@co76    356.5393233   (  356.5390455 ,   356.5396010  )
#  6   xypos[1]@co76    12.8220185    (  12.8217407  ,   12.8222962   )
#  7   intflux@co76        1.03       (     0.10     ,     200.00     )
#  8   sbser[0]@co76       0.16       (     0.01     ,      1.00      )
#  9   ge_pa@co76          90.00      (     0.00     ,     180.00     )
#  10  ge_q@co76           2.00       (     1.00     ,      10.00     )
#  11  intflux@ci21        0.65       (     0.10     ,     200.00     )
#  12  sbser[0]@ci21       0.16       (     0.01     ,      1.00      )
#  13  ge_q@ci21           2.00       (     1.00     ,      10.00     )
#  14  intflux@h2o         0.36       (     0.10     ,     200.00     )
#  15  sbser[0]@h2o        0.12       (     0.01     ,      1.00      )
#  16  ge_q@h2o            2.00       (     1.00     ,      10.00     )
#  17  intflux@cont        0.00       (     0.00     ,      0.01      )
#  18  sbser[0]@cont       0.10       (     0.01     ,      0.30      )
#  19  alpha@cont          3.78       (     3.00     ,      4.50      )
#  20  pa@cont             8.00       (    -52.00    ,      68.00     )
#  21  inc@cont            29.00      (     0.00     ,      45.00     )
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ndim:    22
# outdir:  bx610_band6_uv_ab

# %%
gmake.fit_iterate(fit_dct,sampler,nstep=inp_dct['optimize']['niter'])
# Out:
#      0  627573093        inf
#      1  627573093        inf
#      2  627573093        inf
#      3  627573093        inf
#      4  627573093        inf
#      5  627573093        inf
#      6  627573093        inf
#      7  627573093        inf
#      8  627573093        inf
#      9  627573093        inf
#     10  627573093  628455271
#     11  627573093  628228655
#     12  627573093  627883684
#     13  627573093  627775670
#     14  627573093  627754209
#     15  627573093  627702615
#     16  627573093  627691977
#     17  627573093  627680908
#     18  627573093  627676443
#     19  627573093  627672930
#     20  627573093  627672384
#     21  627573093  627668597
#     22  627573093  627652183
#     24  627573093  627641735
#     26  627573093  627630698
#     28  627573093  627628867
#     30  627573093  627628828
#     32  627573093  627627414
#     34  627573093  627626346
#     36  627573093  627624805
#     38  627573093  627621943
#     40  627573093  627617798
#     64  627572845  627627302
#     66  627572845  627625002
#     68  627572845  627623280
#     70  627572845  627620805
#     71  627572845  627615243
#     73  627572845  627614668
#     75  627572845  627610864
#     76  627572845  627608609
#     78  627572845  627606689
#     80  627572845  627593797
#     81  627572845  627593615
#     83  627572845  627592646
#     85  627572845  627590843
#     87  627572845  627589936
#     89  627572845  627589828
#     91  627572845  627583983
#     93  627572845  627583096
#     95  627572845  627583012
#     97  627572845  627582193
#     99  627572845  627578803
#    101  627572845  627578771
#    103  627572845  627578387
#    104  627572845  627578326
#    106  627572845  627578123
#    108  627572845  627577999
#    110  627572845  627577570
#    112  627572845  627577147
#    114  627572845  627576883
#    115  627572845  627575983
#    117  627572845  627575671
#    118  627572845  627575491
#    119  627572845  627575421
#    120  627572845  627575320
#    122  627572845  627575296
#    123  627572845  627575242
#    125  627572845  627575051
#    127  627572845  627575043
#    129  627572845  627575000
#    130  627572845  627574717
#    132  627572845  627574577
#    133  627572845  627574477
#    134  627572845  627574433
#    136  627572845  627574340
#    137  627572845  627574316
#    139  627572845  627574243
#    141  627572845  627574202
#    142  627572845  627574145
#    144  627572845  627574087
#    146  627572845  627573836
#    148  627572845  627573797
#    150  627572845  627573775
#    152  627572845  627573745
#    154  627572845  627573725
#    155  627572845  627573663
#    156  627572845  627573643
#    157  627572845  627573513
#    159  627572845  627573423
#    160  627572845  627573382
#    162  627572823  627573366
#    164  627572792  627573335
#    165  627572792  627573294
#    166  627572792  627573287
#    168  627572792  627573280
#    170  627572792  627573253
#    172  627572792  627573233
#    174  627572666  627573230
#    175  627572666  627573211
#    176  627572666  627573191
#    177  627572666  627573134
#    179  627572666  627573106
#    180  627572666  627573093
#    181  627572666  627573091
#    182  627572666  627573091
#    183  627572666  627573088
#    185  627572666  627573065
#    186  627572666  627573061
#    187  627572666  627573051
#    189  627572666  627573041
#    190  627572666  627573019
#    192  627572666  627573005
#    194  627572666  627572989
#    196  627572666  627572964
#    198  627572666  627572939
#    200  627572666  627572918
#    201  627572666  627572916
#    202  627572666  627572883
#    204  627572666  627572861
#    206  627572656  627572856
#    207  627572656  627572855
#    209  627572656  627572853
#    211  627572584  627572847
#    213  627572584  627572845
#    215  627572584  627572838
#    217  627572584  627572830
#    219  627572584  627572826
#    221  627572584  627572823
#    222  627572584  627572822
#    223  627572584  627572815
#    225  627572584  627572807
#    226  627572584  627572792
#    228  627572584  627572780
#    230  627572584  627572769
#    232  627572584  627572763
#    233  627572584  627572741
#    235  627572584  627572730
#    237  627572584  627572718
#    238  627572584  627572705
#    239  627572584  627572694
#    240  627572584  627572680
#    242  627572578  627572677
#    243  627572578  627572676
#    245  627572578  627572675
#    246  627572578  627572672
#    248  627572578  627572669
#    249  627572578  627572667
#    251  627572576  627572666
#    252  627572576  627572662
#    253  627572576  627572660
#    254  627572576  627572658
#    255  627572576  627572656
#    256  627572576  627572655
#    257  627572576  627572654
#    258  627572576  627572648
#    259  627572576  627572646
#    260  627572576  627572644
#    261  627572576  627572642
#    263  627572576  627572642
#    264  627572576  627572638
#    266  627572563  627572636
#    267  627572563  627572634
#    269  627572546  627572632
#    271  627572546  627572631
#    273  627572508  627572626
#    274  627572508  627572621
#    275  627572508  627572619
#    277  627572502  627572612
#    279  627572502  627572607
#    280  627572502  627572602
#    281  627572502  627572600
#    282  627572502  627572599
#    283  627572502  627572598
#    284  627572502  627572593
#    285  627572502  627572591
#    287  627572483  627572589
#    288  627572483  627572589
#    289  627572483  627572588
#    291  627572483  627572588
#    292  627572483  627572586
#    294  627572483  627572586
#    296  627572483  627572584
#    298  627572483  627572583
#    300  627572483  627572581
#    302  627572483  627572580
#    303  627572483  627572580
#    304  627572483  627572578
#    305  627572483  627572577
#    306  627572483  627572576
#    308  627572480  627572572
#    309  627572480  627572567
#    310  627572480  627572563
#    311  627572480  627572562
#    313  627572467  627572560
#    314  627572467  627572555
#    315  627572467  627572549
#    317  627572467  627572546
#    318  627572467  627572544
#    320  627572467  627572543
#    321  627572467  627572541
#    322  627572467  627572540
#    323  627572467  627572539
#    325  627572467  627572537
#    326  627572467  627572536
#    328  627572467  627572536
#    330  627572467  627572533
#    331  627572467  627572531
#    332  627572467  627572531
#    333  627572467  627572525
#    335  627572462  627572525
#    337  627572456  627572519
#    338  627572456  627572516
#    340  627572446  627572511
#    341  627572446  627572511
#    342  627572446  627572508
#    343  627572446  627572505
#    345  627572446  627572503
#    346  627572446  627572502
#    348  627572441  627572502
#    350  627572436  627572498
#    351  627572436  627572498
#    352  627572436  627572498
#    354  627572436  627572491
#    355  627572436  627572488
#    356  627572436  627572488
#    357  627572436  627572488
#    358  627572436  627572484
#    360  627572436  627572483
#    361  627572436  627572483
#    363  627572407  627572482
#    364  627572407  627572481
#    365  627572407  627572480
#    366  627572407  627572476
#    367  627572407  627572476
#    369  627572407  627572475
#    370  627572407  627572475
#    371  627572407  627572471
#    373  627572407  627572468
#    374  627572407  627572468
#    375  627572407  627572467
#    376  627572407  627572465
#    377  627572407  627572464
#    378  627572407  627572462
#    379  627572407  627572462
#    381  627572407  627572462
#    382  627572407  627572459
#    383  627572407  627572458
#    384  627572407  627572457
#    385  627572407  627572456
#    387  627572394  627572454
#    388  627572394  627572453
#    389  627572394  627572452
#    391  627572394  627572451
#    392  627572394  627572446
#    393  627572394  627572446
#    394  627572394  627572444
#    395  627572394  627572441
#    396  627572394  627572439
#    397  627572394  627572438
#    399  627572376  627572437
#    401  627572376  627572436
#    402  627572376  627572436
#    403  627572376  627572434
#    404  627572376  627572431
#    405  627572376  627572430
#    406  627572376  627572429
#    407  627572376  627572427
#    408  627572376  627572427
#    410  627572376  627572427
#    411  627572376  627572426
#    412  627572376  627572426
#    413  627572376  627572425
#    414  627572376  627572423
#    416  627572376  627572421
#    418  627572376  627572421
#    420  627572372  627572419
#    421  627572372  627572419
#    422  627572372  627572418
#    423  627572372  627572418
#    424  627572372  627572417
#    425  627572372  627572416
#    426  627572372  627572415
#    427  627572372  627572415
#    429  627572372  627572415
#    430  627572372  627572412
#    431  627572372  627572411
#    432  627572372  627572411
#    433  627572372  627572410
#    435  627572369  627572410
#    436  627572369  627572407
#    438  627572369  627572407
#    440  627572366  627572406
#    441  627572366  627572406
#    442  627572366  627572403
#    443  627572366  627572400
#    444  627572366  627572400
#    445  627572366  627572399
#    447  627572356  627572399
#    448  627572356  627572399
#    450  627572356  627572399
#    451  627572356  627572397
#    452  627572356  627572396
#    453  627572356  627572395
#    454  627572356  627572395
#    455  627572356  627572394
#    456  627572356  627572394
#    457  627572356  627572393
#    458  627572356  627572392
#    459  627572356  627572392
#    460  627572356  627572390
#    461  627572356  627572389
#    462  627572356  627572389
#    463  627572356  627572388
#    464  627572356  627572388
#    465  627572356  627572386
#    467  627572356  627572386
#    468  627572356  627572385
#    469  627572356  627572385
#    471  627572354  627572385
#    473  627572354  627572381
#    474  627572354  627572381
#    475  627572354  627572381
#    476  627572354  627572380
#    478  627572340  627572379
#    479  627572340  627572378
#    481  627572340  627572378
#    482  627572340  627572376

# %%
gmake.fit_analyze(inpfile)
# Out:
# ++++++++++++++++++++++++++++++++++++++++
# @ changelog
# ----------------------------------------
# ++++++++++++++++++++++++++++++++++++++++
# @ comments
# ----------------------------------------
# ++++++++++++++++++++++++++++++++++++++++
# @ ignore
# ----------------------------------------
# ++++++++++++++++++++++++++++++++++++++++
# @ co76
# ----------------------------------------
# name                 : 'bx610-co76'
# note                 : 'CO76 of BX610 in BB2'
# vis                  : '../data/bx610/alma/band6/bx610_band6.bb2.cube3.ms'
# samp                 : None
# bmaj                 : None
# bmin                 : None
# bpa                  : None
# type                 : 'linedisk'
# xypos                : [356.5393232703122, 12.822018464960255]
# z                    : 2.21
# pa                   : -62.0
# inc                  : 40.0
# restfreq             : 806.65181
# vsys                 : 115.0
# vrad                 : [0,0.12,0.24,0.36,0.48]
# vrot                 : [0.,220.,220.,220.,220.]
# intflux              : 1.0278
# sbser                : [0.1599,1.]
# vdis                 : [20,20,20,20,20]
# ge_pa                : 90.0
# ge_q                 : 2.0
# method               : 'kinmspy'
# ++++++++++++++++++++++++++++++++++++++++
# @ ci21
# ----------------------------------------
# name                 : 'bx610-ci21'
# note                 : 'CI21 of BX610 in BB2'
# vis                  : '../data/bx610/alma/band6/bx610_band6.bb2.cube3.ms'
# samp                 : None
# bmaj                 : None
# bmin                 : None
# bpa                  : None
# type                 : 'type@co76'
# xypos                : 'xypos@co76'
# z                    : 'z@co76'
# pa                   : 'pa@co76'
# inc                  : 'inc@co76'
# restfreq             : 809.34197
# vsys                 : 'vsys@co76'
# vrad                 : 'vrad@co76'
# vrot                 : 'vrot@co76'
# intflux              : 0.6493
# sbser                : [ 0.1594,1.]
# vdis                 : 'vdis@co76'
# ge_pa                : 'ge_pa@co76'
# ge_q                 : 2.0
# method               : 'kinmspy'
# ++++++++++++++++++++++++++++++++++++++++
# @ h2o
# ----------------------------------------
# name                 : 'bx610-h2o'
# note                 : 'H2O of BX610 in BB3'
# vis                  : '../data/bx610/alma/band6/bx610_band6.bb3.cube3.ms'
# samp                 : None
# bmaj                 : None
# bmin                 : None
# bpa                  : None
# type                 : 'type@co76'
# xypos                : 'xypos@co76'
# z                    : 'z@co76'
# pa                   : 'pa@co76'
# inc                  : 'inc@co76'
# restfreq             : 752.03314
# vsys                 : 'vsys@co76'
# vrad                 : 'vrad@co76'
# vrot                 : 'vrot@co76'
# intflux              : 0.3640
# sbser                : [0.1199,1.]
# vdis                 : 'vdis@co76'
# ge_pa                : 'ge_pa@co76'
# ge_q                 : 2.0
# method               : 'kinmspy'
# ++++++++++++++++++++++++++++++++++++++++
# @ cont
# ----------------------------------------
# name                 : 'bx610-cont'
# note                 : 'submm cont of BX610 in BB1/2/3/4'
# vis                  : '../data/bx610/alma/band6/bx610_band6.bb1.mfs.ms,../data/bx610/alma/band6/bx610_band6.bb2.cube3.ms,../data/bx610/alma/band6/bx610_band6.bb3.cube3.ms,../data/bx610/alma/band6/bx610_band6.bb4.mfs.ms'
# bmaj                 : None
# bmin                 : None
# bpa                  : None
# type                 : 'contdisk'
# xypos                : 'xypos@co76'
# z                    : 'z@co76'
# pa                   : 8
# inc                  : 29
# intflux              : 1.5e-3
# sbser                : [0.10,1.0]
# restfreq             : 251.6825177459
# alpha                : 3.78
# method               : 'disk2d'
# ++++++++++++++++++++++++++++++++++++++++
# @ optimize
# ----------------------------------------
# vsys@co76            : ('a',-120,280,100)
# vrot[1:5]@co76       : ('a',0.,+800.,300)
# vdis[0:5]@co76       : ('a',0.,+800.,80.)
# pa@co76              : ('o',-80,80,80)
# inc@co76             : ('a',5.,85.,45.)
# xypos[0]@co76        : ('o',-1./3600.,+1./3600.,0.5/3600)
# xypos[1]@co76        : ('o',-1./3600.,+1./3600.,0.5/3600)
# intflux@co76         : ('a',0.1,200.0,10.0)
# sbser[0]@co76        : ('a',0.01,1.0,1.0)
# ge_pa@co76           : ('o', -90.0 ,+90.0,89.)
# ge_q@co76            : ('a',1.0,10.0,5)
# intflux@ci21         : ('a',0.1,200.0,0.0)
# sbser[0]@ci21        : ('a',0.01,1.0,1.0)
# ge_q@ci21            : ('a',1.0,10.0,5)
# intflux@h2o          : ('a',0.1,200.0,10.0)
# sbser[0]@h2o         : ('a',0.01,1.0,1.0)
# ge_q@h2o             : ('a',1.0,10.0,5)
# intflux@cont         : ('a',0.1e-3,10.e-3,10e-3)
# sbser[0]@cont        : ('a',0.01,0.30,1.00)
# alpha@cont           : ('a',3,4.5,1.00)
# pa@cont              : ('o',-60,60,50)
# inc@cont             : ('a',0,45.,30)
# method               : 'amoeba'
# niter                : 500
# outdir               : 'bx610_band6_uv_ab'
# outname_replace      : [('../data/bx610/alma/band6/bx610_band6.','b6_'),('../data/bx610/alma/band6/bx610_band4.','b4_')]
# outname_exclude      : ['cube.','mfs.','cube3.']
# Check optimized parameters:
#  0   vsys@co76       =    115.46      <-    115.00      (    -120.00   ,     280.00     )
#  1   vrot[1:5]@co76  =    234.08      <-    220.00      (     0.00     ,     800.00     )
#  2   vdis[0:5]@co76  =     48.58      <-     20.00      (     0.00     ,     800.00     )
#  3   pa@co76         =    -55.86      <-    -62.00      (    -142.00   ,      18.00     )
#  4   inc@co76        =     32.91      <-     40.00      (     5.00     ,      85.00     )
#  5   xypos[0]@co76   =  356.5393261   <-  356.5393233   (  356.5390455 ,   356.5396010  )
#  6   xypos[1]@co76   =  12.8220188    <-  12.8220185    (  12.8217407  ,   12.8222962   )
#  7   intflux@co76    =     1.16       <-     1.03       (     0.10     ,     200.00     )
#  8   sbser[0]@co76   =     0.17       <-     0.16       (     0.01     ,      1.00      )
#  9   ge_pa@co76      =     90.16      <-     90.00      (     0.00     ,     180.00     )
#  10  ge_q@co76       =     1.68       <-     2.00       (     1.00     ,      10.00     )
#  11  intflux@ci21    =     0.65       <-     0.65       (     0.10     ,     200.00     )
#  12  sbser[0]@ci21   =     0.15       <-     0.16       (     0.01     ,      1.00      )
#  13  ge_q@ci21       =     1.49       <-     2.00       (     1.00     ,      10.00     )
#  14  intflux@h2o     =     0.31       <-     0.36       (     0.10     ,     200.00     )
#  15  sbser[0]@h2o    =     0.12       <-     0.12       (     0.01     ,      1.00      )
#  16  ge_q@h2o        =     2.20       <-     2.00       (     1.00     ,      10.00     )
#  17  intflux@cont    =     0.00       <-     0.00       (     0.00     ,      0.01      )
#  18  sbser[0]@cont   =     0.10       <-     0.10       (     0.01     ,      0.30      )
#  19  alpha@cont      =     3.78       <-     3.78       (     3.00     ,      4.50      )
#  20  pa@cont         =     17.82      <-     8.00       (    -52.00    ,      68.00     )
#  21  inc@cont        =     29.03      <-     29.00      (     0.00     ,      45.00     )
# export the model set:             bx610_band6_uv_ab/p_start              (may take some time..)
# -->data_b6_bb2.ms
# imodel@../data/bx610/alma/band6/bx610_band6.bb2.cube3.ms
# write reference model image:
#     imodel@../data/bx610/alma/band6/bx610_band6.bb2.cube3.ms to bx610_band6_uv_ab/p_start/imodel_b6_bb2.fits
# imod2d@../data/bx610/alma/band6/bx610_band6.bb2.cube3.ms
# write reference model image:
#     imod2d@../data/bx610/alma/band6/bx610_band6.bb2.cube3.ms to bx610_band6_uv_ab/p_start/imod2d_b6_bb2.fits
# imod3d@../data/bx610/alma/band6/bx610_band6.bb2.cube3.ms
# write reference model image:
#     imod3d@../data/bx610/alma/band6/bx610_band6.bb2.cube3.ms to bx610_band6_uv_ab/p_start/imod3d_b6_bb2.fits
# write reference model profile:
#     imod3d_prof@co76@../data/bx610/alma/band6/bx610_band6.bb2.cube3.ms to bx610_band6_uv_ab/p_start/imodrp_co76_b6_bb2.fits
# write reference model profile:
#     imod3d_prof@ci21@../data/bx610/alma/band6/bx610_band6.bb2.cube3.ms to bx610_band6_uv_ab/p_start/imodrp_ci21_b6_bb2.fits
# copy ms container: ../data/bx610/alma/band6/bx610_band6.bb2.cube3.ms  to  bx610_band6_uv_ab/p_start/data_b6_bb2.ms
# write ms column: uvmodel@../data/bx610/alma/band6/bx610_band6.bb2.cube3.ms to corrected@bx610_band6_uv_ab/p_start/data_b6_bb2.ms
# copy ms container: ../data/bx610/alma/band6/bx610_band6.bb2.cube3.ms  to  bx610_band6_uv_ab/p_start/data_b6_bb2.ms.contsub
# write ms column: uvmod3d@../data/bx610/alma/band6/bx610_band6.bb2.cube3.ms to corrected@bx610_band6_uv_ab/p_start/data_b6_bb2.ms.contsub
# write ms column: uvmod2d@../data/bx610/alma/band6/bx610_band6.bb2.cube3.ms to data@bx610_band6_uv_ab/p_start/data_b6_bb2.ms.contsub
# Column MODEL_DATA not added; it already exists
# Column CORRECTED_DATA not added; it already exists
# -->data_b6_bb3.ms
# imodel@../data/bx610/alma/band6/bx610_band6.bb3.cube3.ms
# write reference model image:
#     imodel@../data/bx610/alma/band6/bx610_band6.bb3.cube3.ms to bx610_band6_uv_ab/p_start/imodel_b6_bb3.fits
# imod2d@../data/bx610/alma/band6/bx610_band6.bb3.cube3.ms
# write reference model image:
#     imod2d@../data/bx610/alma/band6/bx610_band6.bb3.cube3.ms to bx610_band6_uv_ab/p_start/imod2d_b6_bb3.fits
# imod3d@../data/bx610/alma/band6/bx610_band6.bb3.cube3.ms
# write reference model image:
#     imod3d@../data/bx610/alma/band6/bx610_band6.bb3.cube3.ms to bx610_band6_uv_ab/p_start/imod3d_b6_bb3.fits
# write reference model profile:
#     imod3d_prof@h2o@../data/bx610/alma/band6/bx610_band6.bb3.cube3.ms to bx610_band6_uv_ab/p_start/imodrp_h2o_b6_bb3.fits
# copy ms container: ../data/bx610/alma/band6/bx610_band6.bb3.cube3.ms  to  bx610_band6_uv_ab/p_start/data_b6_bb3.ms
# write ms column: uvmodel@../data/bx610/alma/band6/bx610_band6.bb3.cube3.ms to corrected@bx610_band6_uv_ab/p_start/data_b6_bb3.ms
# copy ms container: ../data/bx610/alma/band6/bx610_band6.bb3.cube3.ms  to  bx610_band6_uv_ab/p_start/data_b6_bb3.ms.contsub
# write ms column: uvmod3d@../data/bx610/alma/band6/bx610_band6.bb3.cube3.ms to corrected@bx610_band6_uv_ab/p_start/data_b6_bb3.ms.contsub
# write ms column: uvmod2d@../data/bx610/alma/band6/bx610_band6.bb3.cube3.ms to data@bx610_band6_uv_ab/p_start/data_b6_bb3.ms.contsub
# Column MODEL_DATA not added; it already exists
# Column CORRECTED_DATA not added; it already exists
# -->data_b6_bb1.ms
# imodel@../data/bx610/alma/band6/bx610_band6.bb1.mfs.ms
# write reference model image:
#     imodel@../data/bx610/alma/band6/bx610_band6.bb1.mfs.ms to bx610_band6_uv_ab/p_start/imodel_b6_bb1.fits
# imod2d@../data/bx610/alma/band6/bx610_band6.bb1.mfs.ms
# write reference model image:
#     imod2d@../data/bx610/alma/band6/bx610_band6.bb1.mfs.ms to bx610_band6_uv_ab/p_start/imod2d_b6_bb1.fits
# imod3d@../data/bx610/alma/band6/bx610_band6.bb1.mfs.ms
# write reference model image:
#     imod3d@../data/bx610/alma/band6/bx610_band6.bb1.mfs.ms to bx610_band6_uv_ab/p_start/imod3d_b6_bb1.fits
# copy ms container: ../data/bx610/alma/band6/bx610_band6.bb1.mfs.ms  to  bx610_band6_uv_ab/p_start/data_b6_bb1.ms
# write ms column: uvmodel@../data/bx610/alma/band6/bx610_band6.bb1.mfs.ms to corrected@bx610_band6_uv_ab/p_start/data_b6_bb1.ms
# copy ms container: ../data/bx610/alma/band6/bx610_band6.bb1.mfs.ms  to  bx610_band6_uv_ab/p_start/data_b6_bb1.ms.contsub
# write ms column: uvmod3d@../data/bx610/alma/band6/bx610_band6.bb1.mfs.ms to corrected@bx610_band6_uv_ab/p_start/data_b6_bb1.ms.contsub
# write ms column: uvmod2d@../data/bx610/alma/band6/bx610_band6.bb1.mfs.ms to data@bx610_band6_uv_ab/p_start/data_b6_bb1.ms.contsub
# -->data_b6_bb4.ms
# imodel@../data/bx610/alma/band6/bx610_band6.bb4.mfs.ms
# write reference model image:
#     imodel@../data/bx610/alma/band6/bx610_band6.bb4.mfs.ms to bx610_band6_uv_ab/p_start/imodel_b6_bb4.fits
# imod2d@../data/bx610/alma/band6/bx610_band6.bb4.mfs.ms
# write reference model image:
#     imod2d@../data/bx610/alma/band6/bx610_band6.bb4.mfs.ms to bx610_band6_uv_ab/p_start/imod2d_b6_bb4.fits
# imod3d@../data/bx610/alma/band6/bx610_band6.bb4.mfs.ms
# write reference model image:
#     imod3d@../data/bx610/alma/band6/bx610_band6.bb4.mfs.ms to bx610_band6_uv_ab/p_start/imod3d_b6_bb4.fits
# copy ms container: ../data/bx610/alma/band6/bx610_band6.bb4.mfs.ms  to  bx610_band6_uv_ab/p_start/data_b6_bb4.ms
# Column MODEL_DATA not added; it already exists
# Column CORRECTED_DATA not added; it already exists
# write ms column: uvmodel@../data/bx610/alma/band6/bx610_band6.bb4.mfs.ms to corrected@bx610_band6_uv_ab/p_start/data_b6_bb4.ms
# copy ms container: ../data/bx610/alma/band6/bx610_band6.bb4.mfs.ms  to  bx610_band6_uv_ab/p_start/data_b6_bb4.ms.contsub
# write ms column: uvmod3d@../data/bx610/alma/band6/bx610_band6.bb4.mfs.ms to corrected@bx610_band6_uv_ab/p_start/data_b6_bb4.ms.contsub
# write ms column: uvmod2d@../data/bx610/alma/band6/bx610_band6.bb4.mfs.ms to data@bx610_band6_uv_ab/p_start/data_b6_bb4.ms.contsub
# Column MODEL_DATA not added; it already exists
# Column CORRECTED_DATA not added; it already exists
# --------------------------------------------------------------------------------
# --- took 41.14849 seconds ---
# p_start:
# {'chisq': 627573102.8454757,
#  'lnprob': -178749337.8285252,
#  'ndata': 80455719.0,
#  'npar': 22,
#  'wdev': array([], dtype=float64)}
# export the model set:              bx610_band6_uv_ab/p_fits              (may take some time..)
# -->data_b6_bb2.ms
# imodel@../data/bx610/alma/band6/bx610_band6.bb2.cube3.ms
# write reference model image:
#     imodel@../data/bx610/alma/band6/bx610_band6.bb2.cube3.ms to bx610_band6_uv_ab/p_fits/imodel_b6_bb2.fits
# imod2d@../data/bx610/alma/band6/bx610_band6.bb2.cube3.ms
# write reference model image:
#     imod2d@../data/bx610/alma/band6/bx610_band6.bb2.cube3.ms to bx610_band6_uv_ab/p_fits/imod2d_b6_bb2.fits
# imod3d@../data/bx610/alma/band6/bx610_band6.bb2.cube3.ms
# write reference model image:
#     imod3d@../data/bx610/alma/band6/bx610_band6.bb2.cube3.ms to bx610_band6_uv_ab/p_fits/imod3d_b6_bb2.fits
# write reference model profile:
#     imod3d_prof@co76@../data/bx610/alma/band6/bx610_band6.bb2.cube3.ms to bx610_band6_uv_ab/p_fits/imodrp_co76_b6_bb2.fits
# write reference model profile:
#     imod3d_prof@ci21@../data/bx610/alma/band6/bx610_band6.bb2.cube3.ms to bx610_band6_uv_ab/p_fits/imodrp_ci21_b6_bb2.fits
# copy ms container: ../data/bx610/alma/band6/bx610_band6.bb2.cube3.ms  to  bx610_band6_uv_ab/p_fits/data_b6_bb2.ms
# write ms column: uvmodel@../data/bx610/alma/band6/bx610_band6.bb2.cube3.ms to corrected@bx610_band6_uv_ab/p_fits/data_b6_bb2.ms
# copy ms container: ../data/bx610/alma/band6/bx610_band6.bb2.cube3.ms  to  bx610_band6_uv_ab/p_fits/data_b6_bb2.ms.contsub
# write ms column: uvmod3d@../data/bx610/alma/band6/bx610_band6.bb2.cube3.ms to corrected@bx610_band6_uv_ab/p_fits/data_b6_bb2.ms.contsub
# write ms column: uvmod2d@../data/bx610/alma/band6/bx610_band6.bb2.cube3.ms to data@bx610_band6_uv_ab/p_fits/data_b6_bb2.ms.contsub
# Column MODEL_DATA not added; it already exists
# Column CORRECTED_DATA not added; it already exists
# -->data_b6_bb3.ms
# imodel@../data/bx610/alma/band6/bx610_band6.bb3.cube3.ms
# write reference model image:
#     imodel@../data/bx610/alma/band6/bx610_band6.bb3.cube3.ms to bx610_band6_uv_ab/p_fits/imodel_b6_bb3.fits
# imod2d@../data/bx610/alma/band6/bx610_band6.bb3.cube3.ms
# write reference model image:
#     imod2d@../data/bx610/alma/band6/bx610_band6.bb3.cube3.ms to bx610_band6_uv_ab/p_fits/imod2d_b6_bb3.fits
# imod3d@../data/bx610/alma/band6/bx610_band6.bb3.cube3.ms
# write reference model image:
#     imod3d@../data/bx610/alma/band6/bx610_band6.bb3.cube3.ms to bx610_band6_uv_ab/p_fits/imod3d_b6_bb3.fits
# write reference model profile:
#     imod3d_prof@h2o@../data/bx610/alma/band6/bx610_band6.bb3.cube3.ms to bx610_band6_uv_ab/p_fits/imodrp_h2o_b6_bb3.fits
# copy ms container: ../data/bx610/alma/band6/bx610_band6.bb3.cube3.ms  to  bx610_band6_uv_ab/p_fits/data_b6_bb3.ms
# write ms column: uvmodel@../data/bx610/alma/band6/bx610_band6.bb3.cube3.ms to corrected@bx610_band6_uv_ab/p_fits/data_b6_bb3.ms
# copy ms container: ../data/bx610/alma/band6/bx610_band6.bb3.cube3.ms  to  bx610_band6_uv_ab/p_fits/data_b6_bb3.ms.contsub
# write ms column: uvmod3d@../data/bx610/alma/band6/bx610_band6.bb3.cube3.ms to corrected@bx610_band6_uv_ab/p_fits/data_b6_bb3.ms.contsub
# write ms column: uvmod2d@../data/bx610/alma/band6/bx610_band6.bb3.cube3.ms to data@bx610_band6_uv_ab/p_fits/data_b6_bb3.ms.contsub
# Column MODEL_DATA not added; it already exists
# Column CORRECTED_DATA not added; it already exists
# -->data_b6_bb1.ms
# imodel@../data/bx610/alma/band6/bx610_band6.bb1.mfs.ms
# write reference model image:
#     imodel@../data/bx610/alma/band6/bx610_band6.bb1.mfs.ms to bx610_band6_uv_ab/p_fits/imodel_b6_bb1.fits
# imod2d@../data/bx610/alma/band6/bx610_band6.bb1.mfs.ms
# write reference model image:
#     imod2d@../data/bx610/alma/band6/bx610_band6.bb1.mfs.ms to bx610_band6_uv_ab/p_fits/imod2d_b6_bb1.fits
# imod3d@../data/bx610/alma/band6/bx610_band6.bb1.mfs.ms
# write reference model image:
#     imod3d@../data/bx610/alma/band6/bx610_band6.bb1.mfs.ms to bx610_band6_uv_ab/p_fits/imod3d_b6_bb1.fits
# copy ms container: ../data/bx610/alma/band6/bx610_band6.bb1.mfs.ms  to  bx610_band6_uv_ab/p_fits/data_b6_bb1.ms
# write ms column: uvmodel@../data/bx610/alma/band6/bx610_band6.bb1.mfs.ms to corrected@bx610_band6_uv_ab/p_fits/data_b6_bb1.ms
# copy ms container: ../data/bx610/alma/band6/bx610_band6.bb1.mfs.ms  to  bx610_band6_uv_ab/p_fits/data_b6_bb1.ms.contsub
# write ms column: uvmod3d@../data/bx610/alma/band6/bx610_band6.bb1.mfs.ms to corrected@bx610_band6_uv_ab/p_fits/data_b6_bb1.ms.contsub
# write ms column: uvmod2d@../data/bx610/alma/band6/bx610_band6.bb1.mfs.ms to data@bx610_band6_uv_ab/p_fits/data_b6_bb1.ms.contsub
# -->data_b6_bb4.ms
# imodel@../data/bx610/alma/band6/bx610_band6.bb4.mfs.ms
# write reference model image:
#     imodel@../data/bx610/alma/band6/bx610_band6.bb4.mfs.ms to bx610_band6_uv_ab/p_fits/imodel_b6_bb4.fits
# imod2d@../data/bx610/alma/band6/bx610_band6.bb4.mfs.ms
# write reference model image:
#     imod2d@../data/bx610/alma/band6/bx610_band6.bb4.mfs.ms to bx610_band6_uv_ab/p_fits/imod2d_b6_bb4.fits
# imod3d@../data/bx610/alma/band6/bx610_band6.bb4.mfs.ms
# write reference model image:
#     imod3d@../data/bx610/alma/band6/bx610_band6.bb4.mfs.ms to bx610_band6_uv_ab/p_fits/imod3d_b6_bb4.fits
# copy ms container: ../data/bx610/alma/band6/bx610_band6.bb4.mfs.ms  to  bx610_band6_uv_ab/p_fits/data_b6_bb4.ms
# Column MODEL_DATA not added; it already exists
# Column CORRECTED_DATA not added; it already exists
# write ms column: uvmodel@../data/bx610/alma/band6/bx610_band6.bb4.mfs.ms to corrected@bx610_band6_uv_ab/p_fits/data_b6_bb4.ms
# copy ms container: ../data/bx610/alma/band6/bx610_band6.bb4.mfs.ms  to  bx610_band6_uv_ab/p_fits/data_b6_bb4.ms.contsub
# write ms column: uvmod3d@../data/bx610/alma/band6/bx610_band6.bb4.mfs.ms to corrected@bx610_band6_uv_ab/p_fits/data_b6_bb4.ms.contsub
# write ms column: uvmod2d@../data/bx610/alma/band6/bx610_band6.bb4.mfs.ms to data@bx610_band6_uv_ab/p_fits/data_b6_bb4.ms.contsub
# --------------------------------------------------------------------------------
# --- took 33.36061 seconds ---
# Column MODEL_DATA not added; it already exists
# Column CORRECTED_DATA not added; it already exists
# p_fits:
# {'chisq': 627572342.8383055,
#  'lnprob': -178748957.8249401,
#  'ndata': 80455719.0,
#  'npar': 22,
#  'wdev': array([], dtype=float64)}
